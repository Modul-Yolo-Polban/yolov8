# %%
# !yolo task=detect mode=predict model=./runs/detect/train4/weights/best.pt source='./temp/cctv2.png' save=True save_txt=True
# Out:
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.9 torch-2.0.1+cu117 CUDA:0 (Tesla T4, 15110MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients
#
# image 1/1 /home/bimad4/yolov8/temp/cctv2.png: 384x640 5 persons, 48.3ms
# Speed: 1.4ms preprocess, 48.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict9
# 1 label saved to runs/detect/predict9/labels

# %%
from IPython.display import Image, display

Image(filename=f'./runs/detect/predict9/cctv2.png')
