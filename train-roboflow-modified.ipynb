# %%
from roboflow import Roboflow

# %cd ~/yolov8/datasets/roboflow

rf = Roboflow(api_key="iBLXysvAlL0QFcR7ox1s")
project = rf.workspace("modulyolopolban").project("yolo-fa0wn")
dataset = project.version(1).download("yolov8")
# Out:
# /home/bimad4/yolov8/datasets/roboflow
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to yolo-1 in yolov8:: 100%|████████████████████████████████████████████████████| 2009/2009 [00:00<00:00, 6842.62it/s]

# %%
# %cd ~/yolov8

# !yolo task=detect mode=train model=./cfg/yolov8.yaml data=./datasets/roboflow/yolo-2/data.yaml epochs=25 batch=16 lr0=0.01
# Out:
# /home/bimad4/yolov8
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# %cd ~/yolov8

# !yolo task=detect mode=train model=./cfg/yolov8.yaml data=./datasets/roboflow/yolo-2/data.yaml epochs=200 batch=16 lr0=0.01
# Out:
# /home/bimad4/yolov8
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
from IPython.display import Image, display

Image(filename=f'./runs/detect/train4/confusion_matrix.png', width=600)

# %%
Image(filename=f'./runs/detect/train4/results.png', width=600)

# %%
Image(filename=f'./runs/detect/train4/val_batch0_pred.jpg', width=600)
